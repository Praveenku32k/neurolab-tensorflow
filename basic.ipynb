# %%
# !pip install keras

# %%
# !pip install tensorflow

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Flatten, Dense
#
# ModuleNotFoundError: No module named 'keras'

# %%
model = Sequential()
# Imports a Flatten layer to convert the image matrix into a vector
# Defines the neural network architecture
model.add( Flatten(input_shape = (28,28) ))
model.add(Dense(512, activation = 'relu'))
model.add(Dense(512, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 10)                5130
#
# ...
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 9.2 MB 23.1 MB/s eta 0:00:01
# ...
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# ...
#   Using cached fonttools-4.39.4-py3-none-any.whl (1.0 MB)
# ...
#      |████████████████████████████████| 3.3 MB 64.9 MB/s eta 0:00:01
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#      |████████████████████████████████| 300 kB 50.7 MB/s eta 0:00:01
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      |████████████████████████████████| 1.2 MB 65.0 MB/s eta 0:00:01
# ...
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/config/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
#  Read in the image
image = mpimg.imread('/config/workspace/Images/car1.jpeg')
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import matplotlib.image as mpimg
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# # demo__001_understanding_images_and_cv_basic

# %%
image_path="/config/workspace/Images/car1.jpeg"

# %%
# !pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 9.2 MB 18.1 MB/s eta 0:00:01     |████████████████                | 4.6 MB 18.1 MB/s eta 0:00:01MB 18.1 MB/s eta 0:00:01
# ...
#   Using cached fonttools-4.39.4-py3-none-any.whl (1.0 MB)
# ...
#      |████████████████████████████████| 300 kB 42.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 46.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 17.3 MB 32.0 MB/s eta 0:00:01
# ...
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      |████████████████████████████████| 3.3 MB 34.3 MB/s eta 0:00:01
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/config/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# !pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 61.8 MB 59.4 MB/s eta 0:00:01    |██▉                             | 5.4 MB 22.9 MB/s eta 0:00:031��██████▋    | 53.3 MB 59.4 MB/s eta 0:00:01████████████████████▋   | 55.2 MB 59.4 MB/s eta 0:00:01████████████████████▋  | 57.2 MB 59.4 MB/s eta 0:00:01�██████████████████▉ | 59.5 MB 59.4 MB/s eta 0:00:01�███████████████████▊| 61.3 MB 59.4 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg #image related ops 
import numpy as np
import cv2 # opencv lib

# %%
car1=mpimg.imread(image_path)

# %%
car1.shape
# Out:
# (168, 300, 3)

# %%
type(car1)
# Out:
# numpy.ndarray

# %%
plt.imshow(car1)

# %%
car1[0]
# Out:
# array([[237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
#        [237, 237, 237],
# ...

# %%
car1[0][0]
# Out:
# array([237, 237, 237], dtype=uint8)

# %%
car1_cv=cv2.imread(image_path)

# %%
plt.imshow(car1_cv)

# %%
car1_cv2_BGR_rgb=cv2.cvtColor(car1_cv,cv2.COLOR_BGR2RGB)
plt.imshow(car1_cv2_BGR_rgb)

# %%
car1_cv2_BGR_GRAY=cv2.cvtColor(car1_cv,cv2.COLOR_BGR2GRAY)
plt.imshow(car1_cv2_BGR_rgb,cmap="gray")

# %%
car1_cv2_BGR_GRAY.shape # black and white are single channel.
# Out:
# (168, 300)

# %% [markdown]
# # understanding compisition of colored images

# %%
def viusaliz_RGB_channel(imgArray=None,figsize=(10,7)):
    # splitting the RGB compements
    B,G,R=cv2.split(imgArray)

    # create zero matrix of shape of image 
    Z=np.zeros(B.shape,dtype=B.dtype)# you can use any channel

    #init subplots
    fig,ax=plt.subplots(2,2,figsize=figsize)

    # plotting the actula image and rgb images 
    [axi.set_axis_off() for axi in ax.ravel()]# ravel means faltten operation .

    ax[0,0].set_title("Original Image")
    ax[0,0].imshow(cv2.merge((R,G,B)))

    ax[0,1].set_title("Red ch Image")
    ax[0,1].imshow(cv2.merge((R,Z,Z)))

    ax[1,0].set_title("Green Ch Image")
    ax[1,0].imshow(cv2.merge((Z,G,Z)))

    ax[1,1].set_title("Blue ch Image")
    ax[1,1].imshow(cv2.merge((Z,Z,B)))

# %%
viusaliz_RGB_channel(imgArray=car1_cv)

# %% [markdown]
# # Random generated image

# %%
random_color_img=np.random.randint(0,255,(6,6,3))
random_color_img.shape
# Out:
# (6, 6, 3)

# %%
viusaliz_RGB_channel(imgArray=random_color_img)

# %%
random_color_img # This is how rgb channel are look like.
# Out:
# array([[[  8,  63,  91],
#         [ 31, 149, 205],
#         [ 76, 100,  30],
#         [ 94, 121,  24],
#         [158,  62,  23],
#         [240,  41,  56]],
#
#        [[ 70, 117,   1],
#         [ 98, 158, 150],
#         [ 97,  32, 112],
#         [ 74, 154, 245],
#         [238,   7, 105],
#         [ 72, 104, 123]],
#
#        [[ 69,   5, 247],
#         [ 72, 169, 161],
#         [171,   9,  68],
#         [169, 137, 109],
#         [193, 177,   6],
#         [134, 122, 132]],
#
#        [[ 12, 201, 249],
#         [ 71,   3, 243],
#         [171, 251,  51],
#         [ 97, 227, 237],
#         [254, 213, 224],
#         [116, 177,  62]],
#
#        [[158, 254, 203],
#         [ 53, 127,  46],
#         [184, 201, 180],
#         [156,  69,  98],
#         [207,  28,  54],
#         [195,  22, 135]],
#
#        [[ 55, 242, 191],
#         [219, 170, 228],
#         [ 60, 249,  16],
#         [142, 242, 141],
#         [ 36, 209,  19],
#         [ 35,  42, 201]]])
